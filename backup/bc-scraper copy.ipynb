# %% [markdown]
# # Bandcamp Artist Discog Scraper
# Based on:
# - nahnhh's [webcrawl2_movie details.ipynb](https://github.com/nahnhh/top-movies-2005-2025/blob/main/webcrawl2_movie%20details.ipynb)
# - diprog's [tls-client-async](https://github.com/diprog/python-tls-client-async) for better client identifiers.
# - greasyfork's [Bandcamp: Show more dates](https://greasyfork.org/en/scripts/537005-bandcamp-show-more-dates/code)
# - dbeley's [bandcamp-library-scraper.py](https://github.com/dbeley/bandcamp-library-scraper/blob/main/bandcamp-library-scraper.py) for `extract-discography` function
#
# Artist list used: `slushwave-bandcamp-links.txt` compiled in Slushwave Social Club Discord server.

# %%
import warnings
warnings.filterwarnings('ignore')
from pathlib import Path
import logging
from rich.logging import RichHandler

FORMAT = '%(message)s'
logging.basicConfig(
    level="INFO", format=FORMAT, datefmt="[%X]", handlers=[RichHandler()]
)
log = logging.getLogger('rich')

# %% [markdown]
# ### Use `tls-client` instead of plain requests
# TLS fingerprinting gives a more browser-like behavior to bypass anti-bot protections.

# %%
from bs4 import BeautifulSoup
from async_tls_client import AsyncSession
import asyncio
import os
import random
import json

# %%
GOOD_PROFILES = Path("good_profiles.json")
with open(GOOD_PROFILES, "r") as f:
		OK_CLIENTS = json.load(f)
class BrowserSession:
	def __init__(self):
		self.requests_made = 0
		self.new_session()
		self.retire_after = random.randint(40, 100)

	def rotate_client(self):
		self.client_identifier = random.choice(OK_CLIENTS)

	def new_session(self):
		self.rotate_client()
		self.session = AsyncSession(
			client_identifier=self.client_identifier,
			random_tls_extension_order=True
		)

		self.session.proxies.update({
			"http": os.getenv("mobileproxyuk"),
			"https": os.getenv("mobileproxyuk"),
		})

		self.session.headers.update({
			"Referer": "https://bandcamp.com/",
			"Accept-Language": "en-US,en;q=0.9",
		})

	async def get(self, url, **kwargs):
		if self.requests_made >= self.retire_after:
			self.new_session()
			self.requests_made = 0
			self.retire_after = random.randint(40, 100)

		resp = await self.session.get(url,**kwargs)
		self.requests_made += 1
		return resp

# %%
async def fetch(urls):
	random.seed(42)
	s = BrowserSession()
	failed = []
	soups = []
	for url in urls:
		r = await s.get(url)
		soup = BeautifulSoup(r.text, 'lxml')
		if soup.title and soup.title.get_text(strip=True) == "Client Challenge":
			failed.append({
				"url": url,
				"profile": s.client_identifier,
				})
			log.warning(f"Client Challenge with {s.client_identifier} for {url}")
			s.new_session()
			continue
		soups.append(soup)
	return soups

# %%
import re
def nozero(text):
	return re.sub(r'[\u200b\u200c\u200d\ufeff]', '', text)

# %% [markdown]
# ### Fetching soup from urls: music page

# %%
urls = [
	'https://illusionarydreaming.bandcamp.com/', # custom grid, no music-grid
	'https://itachitsukiyomi.bandcamp.com/', # 4 columns
	'https://giftsfromhome.bandcamp.com/', # 3 columns
	'https://blackmoon00.bandcamp.com/', # 2 columns
	]
	
soups = await fetch(urls)

print("Albums fetched:")
print([soup.title.get_text(strip=True) for soup in soups])
# Out:
# Albums fetched:
# ['Illusionary ドリーミング', 'Music | itachi ツクヨミ', 'Music | Quà từ Nhà', 'Music | blackmoonブラックムーン']

# %% [markdown]
# #### Extract album urls from music page

# %%
def extract_album_urls(music_page_soup, artist_url=None):
	"""Extract all album urls from the artist's Music page"""
	if not artist_url:
		artist_url = music_page_soup.select_one('meta[property="og:url"]').get('content')
	links = (
		music_page_soup.select("li.music-grid-item a[href]")
		or music_page_soup.select("div.ipCellImage a[href]")
	)
	albums = []
	for a in links:
		href = a["href"]
		if href.startswith("http"):
			albums.append(href)
		else:
			albums.append(artist_url.rstrip("/") + href)

	return albums

# %%
extract_album_urls(soups[3])[:3]
# Out:
# ['https://blackmoon00.bandcamp.com/album/--4',
#  'https://blackmoon00.bandcamp.com/album/--3',
#  'https://blackmoon00.bandcamp.com/album/--2']

# %% [markdown]
# ### Metadata of one track

# %%
t_url = 'https://noproblematapes.bandcamp.com/track/feat-memorykeeper7'
r = await BrowserSession().get(t_url)
soup = BeautifulSoup(r.text, 'lxml')
t_schema = json.loads(soup.select("script[type='application/ld+json']")[0].get_text(strip=True))
t_schema.keys()
# Out:
# dict_keys(['@type', '@id', 'additionalProperty', 'name', 'duration', 'dateModified', 'datePublished', 'inAlbum', 'byArtist', 'publisher', 'copyrightNotice', 'keywords', 'image', 'mainEntityOfPage', '@context'])

# %%
[
  t_schema['byArtist']['name'],
	t_schema['name'],
  t_schema['image']
]
# Out:
# ['NO PROBLEMA TAPES',
#  'لا طريق آخر (feat. memorykeeper7)',
#  'https://f4.bcbits.com/img/a2569838638_10.jpg']

# %%
tralbum_tag = soup.select_one("[data-tralbum]")
t_tralbum = json.loads(tralbum_tag.get("data-tralbum", "{}"))
t_tralbum.keys()
# Out:
# dict_keys(['for the curious', 'current', 'preorder_count', 'hasAudio', 'art_id', 'packages', 'defaultPrice', 'freeDownloadPage', 'FREE', 'PAID', 'artist', 'item_type', 'id', 'last_subscription_item', 'has_discounts', 'is_bonus', 'play_cap_data', 'is_purchased', 'items_purchased', 'is_private_stream', 'is_band_member', 'licensed_version_ids', 'package_associated_license_id', 'has_video', 'tralbum_subscriber_only', 'album_is_preorder', 'album_release_date', 'trackinfo', 'playing_from', 'album_url', 'album_upsell_url', 'url'])

# %%
t_tralbum.get('art_id')
# Out:
# 2569838638

# %%
	# async def get_track_data(self, url):
	# 	async with self.sem:
	# 		r = await self.s.get(url)
	# 		soup = BeautifulSoup(r.text or "", "lxml")

	# 		try:
	# 			t_schema = json.loads(soup.select_one("script[type='application/ld+json']").get_text(strip=True))
	# 		except Exception:
	# 			log.exception(f"Couldn't fetch icon_url from {url}")
	# 			return None

	# 		# --- art id checks ---
	# 		t_art_url = t_schema.get('image').replace("_10.jpg", "_3")
	# 		async with self.lock:
	# 			# Check for cached urls
	# 			if t_art_url in self.seen_art_url:
	# 				return None
	# 			self.seen_art_url.add(t_art_url)

	# 		img = await self.s.get(t_art_url)
	# 		img_hash = hashlib.sha256(img.content).hexdigest()

	# 		async with self.lock:
	# 			# Check for hash dedupes
	# 			if img_hash in self.seen_hash:
	# 				return None
	# 			self.seen_hash.add(img_hash)

	# 		t_artist = nozero(t_schema.get('byArtist', {}).get('name'))
	# 		t_art_id = t_art_url.replace("https://f4.bcbits.com/img/a","").split("_", 1)[0]

	# 		return t_artist, t_art_id

# %%
	# async def get_release_data(self, url):
	# 	async with self.sem:
	# 		r = await self.s.get(url)
	# 		soup = BeautifulSoup(r.text or "", "lxml")

	# 		try:
	# 			t_tralbum = json.loads(soup.select_one("[data-tralbum]").get("data-tralbum", "{}"))
	# 		except Exception:
	# 			log.exception(f"Couldn't fetch data-tralbum from {url}")
	# 			return None

	# 		# --- art id checks ---
	# 		t_art_id = str(t_tralbum.get('art_id')).zfill(10)

	# 		async with self.lock:
	# 			# Check for cached art ids
	# 			if t_art_id in self.seen_art_id:
	# 				return None
	# 			self.seen_art_id.add(t_art_id)

	# 		img = await self.s.get(ARTWORK_URL.format(art_id=t_art_id))
	# 		img_hash = hashlib.blake2b(img.content,digest_size=8).hexdigest()

	# 		async with self.lock:
	# 			# Check for hash dedupes
	# 			if img_hash in self.seen_hash:
	# 				return None
	# 			self.seen_hash.add(img_hash)

	# 		return t_art_id, img_hash

# %% [markdown]
# ### Metadata of one album

# %% [markdown]
# ### Fetching soup from urls: album page

# %%
urls = [
	'https://desertsand.bandcamp.com/album/perli-tal-passat',
	'https://noproblematapes.bandcamp.com/album/--89',
	# 'https://geometriclullaby.bandcamp.com/album/geo-c07'
	]
	
soups = await fetch(urls)

print("Albums fetched:")
print([soup.title.get_text(strip=True) for soup in soups])
# Out:
# Albums fetched:
# ['Perli tal-Passat | desert sand feels warm at night & days of blue skies | desert sand feels warm at night', 'ලෝක දෙකක් අතර | days of blue skies | NO PROBLEMA TAPES']

# %%
import json
album_schema = json.loads(soups[0].select("script[type='application/ld+json']")[0].get_text(strip=True))
tralbum_tag = soups[0].select_one("[data-tralbum]")
tralbum = json.loads(tralbum_tag.get("data-tralbum", "{}"))

[nozero(album_schema['name']), # album name
 nozero(album_schema['byArtist']['name']), # artist name
 album_schema['numTracks'], # number of tracks
 album_schema['keywords'] # tags
]
# Out:
# ['Perli tal-Passat',
#  'desert sand feels warm at night & days of blue skies',
#  14,
#  ['Electronic',
#   'ambient',
#   'chill',
#   'experimental electronic',
#   'memories',
#   'rain',
#   'slushwave',
#   'smooth',
#   'vaporwave',
#   'United Kingdom']]

# %%
album_schema.keys()
# Out:
# dict_keys(['albumReleaseType', '@id', 'mainEntityOfPage', '@type', 'name', 'dateModified', 'albumRelease', 'byArtist', 'publisher', 'numTracks', 'track', 'image', 'keywords', 'datePublished', 'description', 'creditText', 'copyrightNotice', 'comment', 'sponsor', 'additionalProperty', '@context'])

# %%
album_schema['track']['itemListElement']
# Out:
# [{'@type': 'ListItem',
#   'position': 1,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/mintix',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 2597899836},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Mintix',
#    'duration': 'P00H09M03S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/mintix'}},
#  {'@type': 'ListItem',
#   'position': 2,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/mog-dija-tal-primula',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 2030139825},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Mogħdija tal-Primula',
#    'duration': 'P00H12M31S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/mog-dija-tal-primula'}},
#  {'@type': 'ListItem',
#   'position': 3,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/frammenti',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 1599986573},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Frammenti',
#    'duration': 'P00H10M00S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/frammenti'}},
#  {'@type': 'ListItem',
#   'position': 4,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/jiel-tal-img-oddi',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 2029978550},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Ħjiel tal-Imgħoddi',
#    'duration': 'P00H07M15S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/jiel-tal-img-oddi'}},
#  {'@type': 'ListItem',
#   'position': 5,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/modulazzjonijiet-riflessjonijiet',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 3188395874},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Modulazzjonijiet, Riflessjonijiet',
#    'duration': 'P00H10M44S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/modulazzjonijiet-riflessjonijiet'}},
#  {'@type': 'ListItem',
#   'position': 6,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/tfakkira',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 1636084070},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Tfakkira',
#    'duration': 'P00H10M36S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/tfakkira'}},
#  {'@type': 'ListItem',
#   'position': 7,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/meta-kien-twil-il-lejl',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 2341585530},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Meta Kien Twil il-Lejl?',
#    'duration': 'P00H09M09S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/meta-kien-twil-il-lejl'}},
#  {'@type': 'ListItem',
#   'position': 8,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/solipsi-mu',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 3323865140},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Solipsiżmu',
#    'duration': 'P00H10M45S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/solipsi-mu'}},
#  {'@type': 'ListItem',
#   'position': 9,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/qatt-ma-ninsa',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 2719705060},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Qatt Ma Ninsa',
#    'duration': 'P00H12M06S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/qatt-ma-ninsa'}},
#  {'@type': 'ListItem',
#   'position': 10,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/g-ajnejn-odor-tal-inno-enza',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 3607104657},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Għajnejn Ħodor tal-Innoċenza',
#    'duration': 'P00H10M31S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/g-ajnejn-odor-tal-inno-enza'}},
#  {'@type': 'ListItem',
#   'position': 11,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/xorta-minnek',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 3641140471},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Xorta, Minnek',
#    'duration': 'P00H08M55S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/xorta-minnek'}},
#  {'@type': 'ListItem',
#   'position': 12,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/kisi-tal-fidda',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 3349619256},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Kisi tal-Fidda',
#    'duration': 'P00H07M18S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/kisi-tal-fidda'}},
#  {'@type': 'ListItem',
#   'position': 13,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/effu-jonijiet-personali',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 2366168192},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Effużjonijiet Personali',
#    'duration': 'P00H13M38S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/effu-jonijiet-personali'}},
#  {'@type': 'ListItem',
#   'position': 14,
#   'item': {'@type': 'MusicRecording',
#    '@id': 'https://desertsand.bandcamp.com/track/ritmu-tal-ajja',
#    'additionalProperty': [{'@type': 'PropertyValue',
#      'name': 'track_id',
#      'value': 1157093411},
#     {'@type': 'PropertyValue',
#      'name': 'license_name',
#      'value': 'all_rights_reserved'}],
#    'name': 'Ritmu tal-Ħajja',
#    'duration': 'P00H14M40S',
#    'copyrightNotice': 'All Rights Reserved',
#    'mainEntityOfPage': 'https://desertsand.bandcamp.com/track/ritmu-tal-ajja'}}]

# %%
album_schema['description']
# Out:
# 'Mhux dawk kollha li jduru jintilfu...\r\n\r\nTracks 1, 4, 5, 7, 9, 10, 14 by\r\ndesert sand feels warm at night\r\n\r\nTracks 2, 3, 6, 8, 11, 12, 13 by\r\ndays of blue skies'

# %%
album_schema['creditText']
# Out:
# 'days of blue skies:\r\nhttps://daysofblue.bandcamp.com/\r\n\r\nCassette:\r\n\r\nhttps://ephemeraleternal.bandcamp.com/album/perli-tal-passat\r\nhttps://ephemeraleternal.bandcamp.com/album/perli-tal-passat\r\nhttps://ephemeraleternal.bandcamp.com/album/perli-tal-passat'

# %% [markdown]
# #### Get alternative album urls from labels in description/credits

# %%
import re

ALT_ALBUM_URL = re.compile(r"https://[a-zA-Z0-9-]+\.bandcamp\.com/album/\S+")

def extract_alt_album_urls(album_schema):
	text = (
		(album_schema.get("creditText") or "") + " " +
		(album_schema.get("description") or "")
	)
	links = ALT_ALBUM_URL.findall(text)
	# dedupe
	seen = set()
	result = []
	for link in links:
		if link not in seen:
			seen.add(link)
			result.append(link)

	return result

# %%
extract_alt_album_urls(album_schema)
# Out:
# ['https://ephemeraleternal.bandcamp.com/album/perli-tal-passat']

# %%
tralbum.keys()
# Out:
# dict_keys(['for the curious', 'current', 'preorder_count', 'hasAudio', 'art_id', 'packages', 'defaultPrice', 'freeDownloadPage', 'FREE', 'PAID', 'artist', 'item_type', 'id', 'last_subscription_item', 'has_discounts', 'is_bonus', 'play_cap_data', 'is_purchased', 'items_purchased', 'is_private_stream', 'is_band_member', 'licensed_version_ids', 'package_associated_license_id', 'has_video', 'tralbum_subscriber_only', 'featured_track_id', 'initial_track_num', 'is_preorder', 'album_is_preorder', 'album_release_date', 'trackinfo', 'playing_from', 'url', 'use_expando_lyrics'])

# %%
tralbum['id']
# Out:
# 1963114278

# %%
tralbum['trackinfo']
# Out:
# [{'id': 2597899836,
#   'track_id': 2597899836,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/4218c82fa1717e3fabc1efd6da39f5d3/mp3-128/2597899836?p=0&ts=1781403954&t=06d43274b6a6cfcc21430c8a44946cabfcaab7e9&token=1781403954_267cd6da46fac1e9ad85f2bf046d535d0c9039b0'},
#   'artist': None,
#   'title': 'Mintix',
#   'encodings_id': 1997498610,
#   'license_type': 1,
#   'private': None,
#   'track_num': 1,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/mintix',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 543.115,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 2030139825,
#   'track_id': 2030139825,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/f122ae7aa92d483010d101bbb1120cf9/mp3-128/2030139825?p=0&ts=1781403954&t=3734f97f49ce152d99c6bde84d8f35626b46886f&token=1781403954_1354eb3f4054b90fdfa3b6718b94cda704e98149'},
#   'artist': None,
#   'title': 'Mogħdija tal-Primula',
#   'encodings_id': 1526582812,
#   'license_type': 1,
#   'private': None,
#   'track_num': 2,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/mog-dija-tal-primula',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 751.118,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 1599986573,
#   'track_id': 1599986573,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/d06d55e79342249ac071b24856fb533a/mp3-128/1599986573?p=0&ts=1781403954&t=972b76bb372d8779121aee51e17553860a014332&token=1781403954_707b574220beb71f98ca3db7618011e1cc80967f'},
#   'artist': None,
#   'title': 'Frammenti',
#   'encodings_id': 3634726379,
#   'license_type': 1,
#   'private': None,
#   'track_num': 3,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/frammenti',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 600.377,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 2029978550,
#   'track_id': 2029978550,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/5957e270c5ae4514d2bdc7d3d2bb9d30/mp3-128/2029978550?p=0&ts=1781403954&t=87c5789d329cde8aa848187365c0da9d58b2103d&token=1781403954_0a1b136ebc5f0fa8c3accb27d25c959b929989f0'},
#   'artist': None,
#   'title': 'Ħjiel tal-Imgħoddi',
#   'encodings_id': 1394898027,
#   'license_type': 1,
#   'private': None,
#   'track_num': 4,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/jiel-tal-img-oddi',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 435.155,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 3188395874,
#   'track_id': 3188395874,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/b1a73908b8a95db16825da5069af372a/mp3-128/3188395874?p=0&ts=1781403954&t=8b3a01838fbfe2db6f5d0f97ad0464d524eb7e01&token=1781403954_cfa12c061fd4618baa5cbfdaa14b16de4f62cf1e'},
#   'artist': None,
#   'title': 'Modulazzjonijiet, Riflessjonijiet',
#   'encodings_id': 1740886858,
#   'license_type': 1,
#   'private': None,
#   'track_num': 5,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/modulazzjonijiet-riflessjonijiet',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 644.972,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 1636084070,
#   'track_id': 1636084070,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/711b89524b52d0d05c9f467050259335/mp3-128/1636084070?p=0&ts=1781403954&t=1af6f8753e5de6d3040b1234d6c06eadf64a2353&token=1781403954_0e220a8241ef16c314e41f96bffff0e217ee9a30'},
#   'artist': None,
#   'title': 'Tfakkira',
#   'encodings_id': 3932134468,
#   'license_type': 1,
#   'private': None,
#   'track_num': 6,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/tfakkira',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 636.311,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 2341585530,
#   'track_id': 2341585530,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/6d5d8f949cd9625e374f5d8c6906c68b/mp3-128/2341585530?p=0&ts=1781403954&t=cd12cfc74f8f5cff0bd8fdbb1aec42d582b58707&token=1781403954_0ac2e508b145da3468ea438fcb22fd6708040859'},
#   'artist': None,
#   'title': 'Meta Kien Twil il-Lejl?',
#   'encodings_id': 3091583949,
#   'license_type': 1,
#   'private': None,
#   'track_num': 7,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/meta-kien-twil-il-lejl',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 549.659,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 3323865140,
#   'track_id': 3323865140,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/e2b4940ca67d38b222387bc425c85fcb/mp3-128/3323865140?p=0&ts=1781403954&t=b4fe49cb4c35a0173f23b72cfe84106f92ba271f&token=1781403954_18a0357614949f79ee8c55d8ca556acb215065a4'},
#   'artist': None,
#   'title': 'Solipsiżmu',
#   'encodings_id': 2101402325,
#   'license_type': 1,
#   'private': None,
#   'track_num': 8,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/solipsi-mu',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 645.083,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 2719705060,
#   'track_id': 2719705060,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/7d9432686d2154006803702bd628fc3c/mp3-128/2719705060?p=0&ts=1781403954&t=bebc84cf83c65a0c48a597226b14ae94931188ef&token=1781403954_9632e31a6908db611f0c6fce00ef641294cab27c'},
#   'artist': None,
#   'title': 'Qatt Ma Ninsa',
#   'encodings_id': 1293922251,
#   'license_type': 1,
#   'private': None,
#   'track_num': 9,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/qatt-ma-ninsa',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 726.842,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 3607104657,
#   'track_id': 3607104657,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/e807b30591ca00fabe0d6f69b8c09407/mp3-128/3607104657?p=0&ts=1781403954&t=75c0aa650b90f2d5ab3da276104568b7088e7f1a&token=1781403954_3a0149e1e118bb235b644b07398f55c01d8ec5d5'},
#   'artist': None,
#   'title': 'Għajnejn Ħodor tal-Innoċenza',
#   'encodings_id': 4186290781,
#   'license_type': 1,
#   'private': None,
#   'track_num': 10,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/g-ajnejn-odor-tal-inno-enza',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 631.239,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 3641140471,
#   'track_id': 3641140471,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/6b3efafeab8ab60eeaa6861ebaabd54f/mp3-128/3641140471?p=0&ts=1781403954&t=7914732a6946015dc1b97bea2f13dc406ee2c787&token=1781403954_413ed9a9ddc7dbc442dc126c90fa084e0ee8da71'},
#   'artist': None,
#   'title': 'Xorta, Minnek',
#   'encodings_id': 1293897661,
#   'license_type': 1,
#   'private': None,
#   'track_num': 11,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/xorta-minnek',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 535.385,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 3349619256,
#   'track_id': 3349619256,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/26f8a02ee4ae17c886a05d520a31f4ee/mp3-128/3349619256?p=0&ts=1781403954&t=94f2bd3214e2877818f61e05029e2da8b966ae6c&token=1781403954_252e4443fc069c95f0e5748dd6ea598477c626a0'},
#   'artist': None,
#   'title': 'Kisi tal-Fidda',
#   'encodings_id': 936101447,
#   'license_type': 1,
#   'private': None,
#   'track_num': 12,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/kisi-tal-fidda',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 438.447,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 2366168192,
#   'track_id': 2366168192,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/32d7622971b110bb1e604428e39c024f/mp3-128/2366168192?p=0&ts=1781403954&t=952e7bc0feeb129c3404e8b03f2c200fc80f0485&token=1781403954_e31adaa4c991fc04b64d609c10bf120441333e15'},
#   'artist': None,
#   'title': 'Effużjonijiet Personali',
#   'encodings_id': 1724960163,
#   'license_type': 1,
#   'private': None,
#   'track_num': 13,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/effu-jonijiet-personali',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 818.684,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None},
#  {'id': 1157093411,
#   'track_id': 1157093411,
#   'file': {'mp3-128': 'https://t4.bcbits.com/stream/e0fdeb2c6bb93bc7512ee9bef0c71f19/mp3-128/1157093411?p=0&ts=1781403954&t=5175e144e0862351af44d0bd410fee7c01824eba&token=1781403954_b23e4e2079839d6f627f3c1255d3d97e556b6403'},
#   'artist': None,
#   'title': 'Ritmu tal-Ħajja',
#   'encodings_id': 3470891356,
#   'license_type': 1,
#   'private': None,
#   'track_num': 14,
#   'album_preorder': False,
#   'unreleased_track': False,
#   'title_link': '/track/ritmu-tal-ajja',
#   'has_lyrics': False,
#   'has_info': False,
#   'streaming': 1,
#   'is_downloadable': True,
#   'has_free_download': None,
#   'free_album_download': False,
#   'duration': 880.626,
#   'lyrics': None,
#   'sizeof_lyrics': 0,
#   'is_draft': False,
#   'video_source_type': None,
#   'video_source_id': None,
#   'video_mobile_url': None,
#   'video_poster_url': None,
#   'video_id': None,
#   'video_caption': None,
#   'video_featured': None,
#   'alt_link': None,
#   'encoding_error': None,
#   'encoding_pending': None,
#   'play_count': None,
#   'is_capped': None,
#   'track_license_id': None}]

# %%
# Get all track urls
import isodate
import pandas as pd
df = pd.DataFrame([
	{
		"url": t['item']['@id']
	}
	for t in album_schema["track"]["itemListElement"]
])
print(df)
# Out:
#                                                   url
# 0        https://desertsand.bandcamp.com/track/mintix
# 1   https://desertsand.bandcamp.com/track/mog-dija...
# 2     https://desertsand.bandcamp.com/track/frammenti
# 3   https://desertsand.bandcamp.com/track/jiel-tal...
# 4   https://desertsand.bandcamp.com/track/modulazz...
# 5      https://desertsand.bandcamp.com/track/tfakkira
# 6   https://desertsand.bandcamp.com/track/meta-kie...
# 7    https://desertsand.bandcamp.com/track/solipsi-mu
# 8   https://desertsand.bandcamp.com/track/qatt-ma-...
# 9   https://desertsand.bandcamp.com/track/g-ajnejn...
# 10  https://desertsand.bandcamp.com/track/xorta-mi...
# 11  https://desertsand.bandcamp.com/track/kisi-tal...
# 12  https://desertsand.bandcamp.com/track/effu-jon...
# 13  https://desertsand.bandcamp.com/track/ritmu-ta...

# %% [markdown]
# #### Get unique track arts
# This is how bandcamp art ID works:
# 1. Bandcamp generates a unique art_ID for each time you upload a track art.
# 2. The rest uses art_ID from the album art.
#
# We can drop duplicates based on image hash, with some cases we have to delete manually (dobs album).

# %%
import re
import hashlib

async def get_art_id(url):
	session = BrowserSession()
	r = await session.get(url)
	soup = BeautifulSoup(r.text or "", "lxml")

	icon_url = soup.select_one('link[rel="shortcut icon"]')['href']

	img = await session.get(icon_url)
	img_hash = hashlib.sha256(img.content).hexdigest()

	art_id = re.search(r'a(\d+)_', icon_url).group(1)

	return art_id, img_hash


results = await asyncio.gather(
    *(get_art_id(url) for url in df["url"])
)

art_df = pd.DataFrame(
    results,
    columns=["art_id", "img_hash"]
)

print(art_df)
# Out:
#         art_id                                           img_hash
# 0   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 1   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 2   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 3   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 4   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 5   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 6   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 7   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 8   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 9   3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 10  3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 11  3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 12  3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...
# 13  3561606714  8200576d3dc0bbf34463c68e8308d88d976bea211646e3...

# %%
print(f"Total unique art IDs: {art_df['art_id'].nunique()}, Unique Image Hashes: {art_df['img_hash'].nunique()}")
# Out:
# Total unique art IDs: 1, Unique Image Hashes: 1

# %% [markdown]
# #### Get all dates of the album

# %%
tralbum = json.loads(tralbum_tag["data-tralbum"])['current']
tralbum2 = json.loads(tralbum_tag["data-tralbum"])['trackinfo']

# %%
[nozero(tralbum['title']), # album name
 tralbum['art_id'], # album image id: 2569838638 in https://f4.bcbits.com/img/a2569838638_10.jpg
 tralbum['new_date'], # date first created draft
 tralbum['mod_date'], # date last modified
 tralbum['publish_date'], # publication date
 tralbum['release_date'] # release date
 ]
# Out:
# ['Perli tal-Passat',
#  3561606714,
#  '16 Dec 2024 00:19:06 GMT',
#  '15 Jul 2025 14:55:17 GMT',
#  '16 Dec 2024 17:49:51 GMT',
#  '16 Dec 2024 00:00:00 GMT']

# %%
# Get all track durations
import pandas as pd
track_df = pd.DataFrame([
	{
		"position": t['track_num'],
		"duration": t['duration'],
	}
	for t in tralbum2
])
print(track_df)
# Out:
#     position  duration
# 0          1   543.115
# 1          2   751.118
# 2          3   600.377
# 3          4   435.155
# 4          5   644.972
# 5          6   636.311
# 6          7   549.659
# 7          8   645.083
# 8          9   726.842
# 9         10   631.239
# 10        11   535.385
# 11        12   438.447
# 12        13   818.684
# 13        14   880.626

# %% [markdown]
# #### Adding up total runtime of the album:

# %%
from datetime import timedelta
print(timedelta(seconds=int(track_df["duration"].sum())))
# Out:
# 2:27:17
